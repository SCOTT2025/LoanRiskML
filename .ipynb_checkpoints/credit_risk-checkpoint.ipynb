# %% [markdown]
# # INTRODUCTION
#
# This notebook looks into developing and End-to-End machine learning pipeline in Python to predict the probability of default (Credit risk modelling concept) using financil dataset
